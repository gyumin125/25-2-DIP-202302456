# %%
import matplotlib.pyplot as plt # matplotlib 영상처리시 자주 쓰는 라이브러리임.

# %%
I = plt.imread('IMG_for_HW00.jpg')

# %%
I.shape
# Out:
# (4032, 2268, 3)

# %%
I.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(I)
plt.show()
